# %% [markdown]
# <a href="https://colab.research.google.com/github/Edgar295/CEGID-ACADEMY-DA/blob/main/C%C3%B3pia_de_Damos_lhe_as_boas_vindas_ao_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mental Health Student Case

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from os import read

# %%
student_data = pd.read_csv("/content/projecto proposta dados.csv")

# %%
student_data.head()
# Out:
#    Age  Gender Country Academic_Level Most_Used_Platform Purpose_Of_Use  \
# 0   21    Male   Other  Undergraduate           Facebook     Networking
# 1   23  Female   Other       Graduate           LinkedIn      Education
# 2   22    Male  Canada  Undergraduate          Instagram  Entertainment
# 3   18    Male   Other    High School           Snapchat  Entertainment
# 4   24  Female   Other       Graduate           Facebook     Networking
#
#    Avg_Daily_Usage_Hours  Daily_Unlocks  Study_Hours  Physical_Activity_Hours  \
# 0                    4.0            134          4.5                      2.2
# 1                    1.6             73          7.0                      2.4
# 2                    4.6            166          4.0                      1.8
# 3                    7.0            220          1.0                      1.7
# 4                    7.5            237          1.0                      1.1
#
#    Sleep_Hours_Per_Night Stress_Level  Mental_Health_Score
# ...

# %%
student_data.describe()
# Out:
#               Age  Avg_Daily_Usage_Hours  Daily_Unlocks  Study_Hours  \
# count  5000.00000            5000.000000    5000.000000  5000.000000
# mean     20.82180               5.078460     171.452600     3.008420
# std       1.73662               1.653913      42.858254     1.637018
# min      18.00000               1.000000      62.000000     0.300000
# 25%      19.00000               3.800000     140.000000     1.500000
# 50%      21.00000               5.000000     171.000000     2.800000
# 75%      22.00000               6.300000     204.000000     4.200000
# max      24.00000               8.800000     273.000000     8.300000
#
#        Physical_Activity_Hours  Sleep_Hours_Per_Night  Mental_Health_Score
# count              5000.000000            5000.000000          5000.000000
# mean                  1.751000               6.634580             6.230980
# std                   0.668398               1.221391             1.278701
# ...

# %%
student_data.Academic_Level.value_counts()
# Out:
# Academic_Level
# Undergraduate    3632
# Graduate          918
# High School       450
# Name: count, dtype: int64

# %%
student_data.Gender.value_counts()
# Out:
# Gender
# Male      2635
# Female    2365
# Name: count, dtype: int64

# %%
student_data.Country.value_counts()
# Out:
# Country
# Other        1880
# India         389
# USA           355
# Canada        230
# Australia     198
#              ...
# Armenia         1
# Bosnia          1
# Kuwait          1
# Yemen           1
# Syria           1
# Name: count, Length: 111, dtype: int64

# %%
display(student_data.dtypes.to_frame("dtype"))
display(student_data.isna().sum().to_frame("missing"))
print("Duplicados:", student_data.duplicated().sum())
# Out:
#                            dtype
# Age                        int64
# Gender                    object
# Country                   object
# Academic_Level            object
# Most_Used_Platform        object
# Purpose_Of_Use            object
# Avg_Daily_Usage_Hours    float64
# Daily_Unlocks              int64
# Study_Hours              float64
# Physical_Activity_Hours  float64
# Sleep_Hours_Per_Night    float64
# Stress_Level              object
# Mental_Health_Score      float64
#                          missing
# Age                            0
# Gender                         0
# Country                        0
# Academic_Level                 0
# Most_Used_Platform             0
# Purpose_Of_Use                 0
# Avg_Daily_Usage_Hours          0
# Daily_Unlocks                  0
# Study_Hours                    0
# Physical_Activity_Hours        0
# Sleep_Hours_Per_Night          0
# Stress_Level                   0
# Mental_Health_Score            0
# Duplicados: 2

# %%
display(student_data.describe(include="all").T)
num_cols=student_data.select_dtypes(include=np.number).columns.tolist()
cat_cols=student_data.select_dtypes(include="object").columns.tolist()
print("Numéricas:", num_cols)
print("Categóricas:", cat_cols)
# Out:
#                           count unique            top  freq      mean  \
# Age                      5000.0    NaN            NaN   NaN   20.8218
# Gender                     5000      2           Male  2635       NaN
# Country                    5000    111          Other  1880       NaN
# Academic_Level             5000      3  Undergraduate  3632       NaN
# Most_Used_Platform         5000     12      Instagram  1130       NaN
# Purpose_Of_Use             5000      4  Entertainment  2552       NaN
# Avg_Daily_Usage_Hours    5000.0    NaN            NaN   NaN   5.07846
# Daily_Unlocks            5000.0    NaN            NaN   NaN  171.4526
# Study_Hours              5000.0    NaN            NaN   NaN   3.00842
# Physical_Activity_Hours  5000.0    NaN            NaN   NaN     1.751
# Sleep_Hours_Per_Night    5000.0    NaN            NaN   NaN   6.63458
# Stress_Level               5000      4      Very High  1621       NaN
# ...

# %%
for col in num_cols:
    plt.figure(figsize=(7,4))
    sns.histplot(student_data[col], kde=True)
    plt.title(f"Distribuição — {col}")
    plt.tight_layout()
    plt.show()

# %%
corr=student_data[num_cols].corr()
plt.figure(figsize=(9,7))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="vlag", center=0)
plt.title("Matriz de correlação")
plt.tight_layout(); plt.show()
display(corr["Mental_Health_Score"].sort_values())
# Out:
# Avg_Daily_Usage_Hours     -0.816453
# Daily_Unlocks             -0.790851
# Age                        0.100785
# Physical_Activity_Hours    0.521374
# Study_Hours                0.752626
# Sleep_Hours_Per_Night      0.766430
# Mental_Health_Score        1.000000
# Name: Mental_Health_Score, dtype: float64

# %%
checks={
"Age fora de [0,100]":((student_data.Age<0)|(student_data.Age>100)).sum(),
"Uso diário < 0":(student_data.Avg_Daily_Usage_Hours<0).sum(),
"Sono <= 0":(student_data.Sleep_Hours_Per_Night<=0).sum(),
"Score fora de [0,10]":((student_data.Mental_Health_Score<0)|(student_data.Mental_Health_Score>10)).sum()
}
display(pd.Series(checks))
# Out:
# Age fora de [0,100]     0
# Uso diário < 0          0
# Sono <= 0               0
# Score fora de [0,10]    0
# dtype: int64

# %%
stress_order=["Low","Medium","High","Very High"]
display(student_data.groupby("Stress_Level").Mental_Health_Score.agg(["mean","std","count"]).reindex(stress_order))
plt.figure(figsize=(7,4))
sns.barplot(data=student_data,x="Stress_Level",y="Mental_Health_Score",order=stress_order,errorbar="ci")
plt.title("Mental Health Score por nível de stress"); plt.tight_layout(); plt.show()
# Out:
#                   mean       std  count
# Stress_Level
# Low           7.840217  0.723187    644
# Medium        7.135907  0.916431   1295
# High          6.025417  0.830395   1440
# Very High     5.051326  0.663711   1621

# %%
targets=["Avg_Daily_Usage_Hours","Daily_Unlocks","Study_Hours","Physical_Activity_Hours","Sleep_Hours_Per_Night"]
for col in targets:
    plt.figure(figsize=(7,4))
    sns.regplot(data=student_data,x=col,y="Mental_Health_Score",scatter_kws={"alpha":0.25})
    plt.title(f"{col} vs Mental Health Score"); plt.tight_layout(); plt.show()

# %%
for col in ["Most_Used_Platform","Purpose_Of_Use","Academic_Level","Gender"]:
    display(student_data.groupby(col).Mental_Health_Score.agg(["mean","std","count"]).sort_values("mean",ascending=False))
# Out:
#                         mean       std  count
# Most_Used_Platform
# LINE                8.024000  0.140785     50
# VKontakte           7.002500  0.184651     40
# WeChat              6.494444  0.511549     36
# LinkedIn            6.482600  1.403302    523
# Facebook            6.398331  1.302568    719
# Twitter             6.346753  1.293795    462
# YouTube             6.216497  1.357170    491
# Instagram           6.194071  1.287182   1130
# Snapchat            6.123095  1.295104    420
# TikTok              5.993355  1.163742    918
# KakaoTalk           5.983333  0.127615     36
# WhatsApp            5.578286  0.505587    175
#                     mean       std  count
# Purpose_Of_Use
# Networking      6.378562  1.273514    793
# Education       6.348903  1.367688   1094
# News            6.318895  1.237956    561
# Entertainment   6.115243  1.238906   2552
#                     mean       std  count
# Academic_Level
# Graduate        6.391176  1.419339    918
# ...

# %%
for col in ["Most_Used_Platform","Purpose_Of_Use","Academic_Level","Gender"]:
    display(student_data.groupby(col).Mental_Health_Score.agg(["mean","std","count"]).sort_values("mean",ascending=False))
# Out:
#                         mean       std  count
# Most_Used_Platform
# LINE                8.024000  0.140785     50
# VKontakte           7.002500  0.184651     40
# WeChat              6.494444  0.511549     36
# LinkedIn            6.482600  1.403302    523
# Facebook            6.398331  1.302568    719
# Twitter             6.346753  1.293795    462
# YouTube             6.216497  1.357170    491
# Instagram           6.194071  1.287182   1130
# Snapchat            6.123095  1.295104    420
# TikTok              5.993355  1.163742    918
# KakaoTalk           5.983333  0.127615     36
# WhatsApp            5.578286  0.505587    175
#                     mean       std  count
# Purpose_Of_Use
# Networking      6.378562  1.273514    793
# Education       6.348903  1.367688   1094
# News            6.318895  1.237956    561
# Entertainment   6.115243  1.238906   2552
#                     mean       std  count
# Academic_Level
# Graduate        6.391176  1.419339    918
# ...

# %%
display(student_data.groupby('Country').Mental_Health_Score.agg(['mean', 'std', 'count']).sort_values('mean', ascending=False))
# Out:
#                     mean       std  count
# Country
# Malta           8.350000  0.494975      2
# Chile           8.100000  0.141421      2
# Iraq            8.075000  0.170783      4
# Slovakia        8.066667  0.115470      3
# Bulgaria        8.050000  0.070711      2
# ...                  ...       ...    ...
# Norway          4.916667  0.132916      6
# Latvia          4.900000  0.115470      4
# Trinidad        4.900000  0.200000      4
# Bhutan          4.850000  0.212132      2
# Czech Republic  3.975000  0.236291      4
#
# [111 rows x 3 columns]

# %%
from scipy.stats import pearsonr
rows=[]
for col in targets:
    r,p=pearsonr(student_data[col],student_data.Mental_Health_Score)
    rows.append([col,r,p])
display(pd.DataFrame(rows,columns=["variable","pearson_r","p_value"]).sort_values("pearson_r"))
# Out:
#                   variable  pearson_r  p_value
# 0    Avg_Daily_Usage_Hours  -0.816453      0.0
# 1            Daily_Unlocks  -0.790851      0.0
# 3  Physical_Activity_Hours   0.521374      0.0
# 2              Study_Hours   0.752626      0.0
# 4    Sleep_Hours_Per_Night   0.766430      0.0

# %%
avg_mental_health_by_country = student_data.groupby('Country')['Mental_Health_Score'].mean().sort_values(ascending=False).reset_index()

plt.figure(figsize=(15, 8)) # Ajusta o tamanho da figura para acomodar muitos países
sns.barplot(x='Country', y='Mental_Health_Score', data=avg_mental_health_by_country, palette='viridis')
plt.title('Média da Pontuação de Saúde Mental por País')
plt.xlabel('País')
plt.ylabel('Média da Pontuação de Saúde Mental')
plt.xticks(rotation=90) # Rotaciona os rótulos do eixo X para melhor legibilidade
plt.tight_layout() # Ajusta o layout para evitar sobreposição de elementos
plt.show()
# Out:
# /tmp/ipykernel_5708/77924145.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country', y='Mental_Health_Score', data=avg_mental_health_by_country, palette='viridis')

# %%
from scipy.stats import pearsonr
rows=[]
for col in targets:
    r,p=pearsonr(student_data[col],student_data.Mental_Health_Score)
    rows.append([col,r,p])
display(pd.DataFrame(rows,columns=["variable","pearson_r","p_value"]).sort_values("pearson_r"))
# Out:
#                   variable  pearson_r  p_value
# 0    Avg_Daily_Usage_Hours  -0.816453      0.0
# 1            Daily_Unlocks  -0.790851      0.0
# 3  Physical_Activity_Hours   0.521374      0.0
# 2              Study_Hours   0.752626      0.0
# 4    Sleep_Hours_Per_Night   0.766430      0.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

X=student_data.drop(columns="Mental_Health_Score"); y=student_data.Mental_Health_Score
cat=X.select_dtypes("object").columns.tolist()
num=X.select_dtypes(exclude="object").columns.tolist()
pre=ColumnTransformer([("num",StandardScaler(),num),("cat",OneHotEncoder(handle_unknown="ignore"),cat)])
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.20,random_state=42)

models={"Linear Regression":LinearRegression(),"Ridge":Ridge(alpha=1),
        "Random Forest":RandomForestRegressor(n_estimators=300,random_state=42,n_jobs=-1),
        "Gradient Boosting":GradientBoostingRegressor(random_state=42)}
results=[]; fitted={}
for name,m in models.items():
    pipe=Pipeline([("preprocessor",pre),("model",m)])
    pipe.fit(X_train,y_train); pred=pipe.predict(X_test); fitted[name]=pipe
    results.append([name,mean_absolute_error(y_test,pred),mean_squared_error(y_test,pred)**.5,r2_score(y_test,pred)])
results_df=pd.DataFrame(results,columns=["Model","MAE","RMSE","R2"]).sort_values("RMSE")
display(results_df)
# Out:
#                Model       MAE      RMSE        R2
# 2      Random Forest  0.271290  0.377980  0.917613
# 3  Gradient Boosting  0.404067  0.514409  0.847406
# 0  Linear Regression  0.469180  0.598591  0.793376
# 1              Ridge  0.470304  0.599049  0.793060

# %%
best_name=results_df.iloc[0].Model
pred=fitted[best_name].predict(X_test)
plt.figure(figsize=(6,6)); sns.scatterplot(x=y_test,y=pred,alpha=.5)
lims=[min(y_test.min(),pred.min()),max(y_test.max(),pred.max())]
plt.plot(lims,lims,"k--"); plt.xlabel("Observado"); plt.ylabel("Previsto")
plt.title(f"Observado vs previsto — {best_name}"); plt.tight_layout(); plt.show()

residuals=y_test-pred
plt.figure(figsize=(7,4)); sns.histplot(residuals,kde=True)
plt.title(f"Resíduos — {best_name}"); plt.tight_layout(); plt.show()
